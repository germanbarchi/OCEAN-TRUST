# %%
import glob
from IPython.display import Audio
import librosa

# %%
# No speech samples with music

# %%
best_no_speech_music=['qpwcdPnPeFM.000.wav',
'nex61B854Ms.003.wav',
'KppCIwj0hC4.004.wav',
'zMXfMcqpPwQ.005.wav',
'qpwcdPnPeFM.004.wav',
'4kYaYIcuLpM.000.wav']

# %%
audio_dir='/home/german/Documentos/Trust/First_Impressions_Dataset/OCEAN_new_structure/data/silero/silero_no_speech/'

# %%
list_ns_m=[]
for audios in best_no_speech_music:
    a=glob.glob(audio_dir+'*/'+audios)
    list_ns_m.append(a[0])

# %%
list_ns_m
# Out:
# ['/home/german/Documentos/Trust/First_Impressions_Dataset/OCEAN_new_structure/data/silero/silero_no_speech/Val/qpwcdPnPeFM.000.wav',
#  '/home/german/Documentos/Trust/First_Impressions_Dataset/OCEAN_new_structure/data/silero/silero_no_speech/Train/nex61B854Ms.003.wav',
#  '/home/german/Documentos/Trust/First_Impressions_Dataset/OCEAN_new_structure/data/silero/silero_no_speech/Train/KppCIwj0hC4.004.wav',
#  '/home/german/Documentos/Trust/First_Impressions_Dataset/OCEAN_new_structure/data/silero/silero_no_speech/Train/zMXfMcqpPwQ.005.wav',
#  '/home/german/Documentos/Trust/First_Impressions_Dataset/OCEAN_new_structure/data/silero/silero_no_speech/Train/qpwcdPnPeFM.004.wav',
#  '/home/german/Documentos/Trust/First_Impressions_Dataset/OCEAN_new_structure/data/silero/silero_no_speech/Test/4kYaYIcuLpM.000.wav']

# %%
y,fs=librosa.core.load(list_ns_m[0],sr=None)
Audio(y,rate=fs)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
y,fs=librosa.core.load(list_ns_m[1],sr=None)
Audio(y,rate=fs)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
y,fs=librosa.core.load(list_ns_m[2],sr=None)
Audio(y,rate=fs)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
y,fs=librosa.core.load(list_ns_m[4],sr=None)
Audio(y,rate=fs)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
y,fs=librosa.core.load(list_ns_m[5],sr=None)
Audio(y,rate=fs)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# No speech samples with no music

# %%
best_no_speech_no_music=['nZC82V87Pm0.001.wav',
'vUKex2msIEU.000.wav',
'mKWscEow1U8.001.wav',
'nKx64KH7Xks.000.wav',
'Fi1ILrwQpSY.004.wav',
'tomb22yfjTc.000.wav',
'HrddpXxWFns.005.wav',
'ymrFbEMNBME.000.wav',
'd4cPiUXpGbc.000.wav',
'tepWDnvIuRg.004.wav',
'l2YS_qsF7SQ.004.wav',
'RbX4q4KceVk.004.wav',
'19pTUX8KfYM.002.wav',
'a5NTqK367wo.004.wav',
'8pM3X-xsD4s.002.wav']

# %%
list_ns_nm=[]
for audios in best_no_speech_no_music:
    a=glob.glob(audio_dir+'*/'+audios)
    list_ns_nm.append(a[0])

# %%
list_ns_nm
# Out:
# ['/home/german/Documentos/Trust/First_Impressions_Dataset/OCEAN_new_structure/data/silero/silero_no_speech/Val/nZC82V87Pm0.001.wav',
#  '/home/german/Documentos/Trust/First_Impressions_Dataset/OCEAN_new_structure/data/silero/silero_no_speech/Val/vUKex2msIEU.000.wav',
#  '/home/german/Documentos/Trust/First_Impressions_Dataset/OCEAN_new_structure/data/silero/silero_no_speech/Val/mKWscEow1U8.001.wav',
#  '/home/german/Documentos/Trust/First_Impressions_Dataset/OCEAN_new_structure/data/silero/silero_no_speech/Val/nKx64KH7Xks.000.wav',
#  '/home/german/Documentos/Trust/First_Impressions_Dataset/OCEAN_new_structure/data/silero/silero_no_speech/Val/Fi1ILrwQpSY.004.wav',
#  '/home/german/Documentos/Trust/First_Impressions_Dataset/OCEAN_new_structure/data/silero/silero_no_speech/Val/tomb22yfjTc.000.wav',
#  '/home/german/Documentos/Trust/First_Impressions_Dataset/OCEAN_new_structure/data/silero/silero_no_speech/Val/HrddpXxWFns.005.wav',
# ...

# %%
y,fs=librosa.core.load(list_ns_nm[0],sr=None)
Audio(y,rate=fs)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
y,fs=librosa.core.load(list_ns_nm[1],sr=None)
Audio(y,rate=fs)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
y,fs=librosa.core.load(list_ns_nm[2],sr=None)
Audio(y,rate=fs)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
y,fs=librosa.core.load(list_ns_nm[4],sr=None)
Audio(y,rate=fs)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
y,fs=librosa.core.load(list_ns_nm[5],sr=None)
Audio(y,rate=fs)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
y,fs=librosa.core.load(list_ns_nm[6],sr=None)
Audio(y,rate=fs)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
y,fs=librosa.core.load(list_ns_nm[7],sr=None)
Audio(y,rate=fs)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
y,fs=librosa.core.load(list_ns_nm[8],sr=None)
Audio(y,rate=fs)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
y,fs=librosa.core.load(list_ns_nm[9],sr=None)
Audio(y,rate=fs)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
y,fs=librosa.core.load(list_ns_nm[10],sr=None)
Audio(y,rate=fs)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
y,fs=librosa.core.load(list_ns_nm[11],sr=None)
Audio(y,rate=fs)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
y,fs=librosa.core.load(list_ns_nm[13],sr=None)
Audio(y,rate=fs)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
y,fs=librosa.core.load(list_ns_nm[14],sr=None)
Audio(y,rate=fs)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
