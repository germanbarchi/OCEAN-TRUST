# %%
import librosa
from IPython.display import Audio
import glob
import matplotlib.pyplot as plt

# %%
audio_dir='/home/gbarchi/Documentos/Trust/OCEAN-TRUST/data/silero/silero_speech_examples/1uC-2TZqplE.003.wav'

# %%
audio_dir
# Out:
# '/home/gbarchi/Documentos/Trust/OCEAN-TRUST/data/silero/silero_speech_examples/1uC-2TZqplE.003.wav'

# %%
y,fs=librosa.core.load(audio_dir,sr=None)

# %%
Audio(y,rate=fs)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
plt.plot(y)

# %%
y_norm=(y-y.min())/(y.max()-y.min())

# %%
plt.plot(y_norm)

# %%
Audio(y_norm,rate=fs)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
y.std()
# Out:
# 0.09881483
